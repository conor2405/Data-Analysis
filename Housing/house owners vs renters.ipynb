# %% [markdown]
# ### Looking at whether homeowners are much better off than renters
# also looking at life stage, satisfaction and if that has changed over time if i can

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

house = pd.read_csv('data/residential property price index quarterly.csv')
sales = pd.read_csv('data/mean sale price monthly.csv')
wage = pd.read_csv('data/earnings data quarterly.csv')
rent = pd.read_csv('data/one bed dublin rents quarterly.csv')

cpi = pd.read_csv('data/CPI excluding housing.csv')
rent = pd.read_csv('data/one bed dublin rents quarterly.csv')
starts = pd.read_csv('data/housing starts.csv')

# %%
rent.head()
# Out:
#                    STATISTIC Label Quarter Number of Bedrooms  \
# 0  RTB Average Monthly Rent Report  2007Q4            One bed
# 1  RTB Average Monthly Rent Report  2008Q1            One bed
# 2  RTB Average Monthly Rent Report  2008Q2            One bed
# 3  RTB Average Monthly Rent Report  2008Q3            One bed
# 4  RTB Average Monthly Rent Report  2008Q4            One bed
#
#         Property Type Location  UNIT   VALUE
# 0  All property types   Dublin  Euro  992.88
# 1  All property types   Dublin  Euro  992.44
# 2  All property types   Dublin  Euro  985.08
# 3  All property types   Dublin  Euro  930.87
# 4  All property types   Dublin  Euro  910.79

# %%
plt.style.use('../graph_style.mplstyle')
# Out:
# Missing colon in file '../graph_style.mplstyle', line 20 ('axes.')

# %%
fig , ax = plt.subplots()

ax.plot([1,2,3,4,5])
ax.set_title('test')
# Out:
# Text(0.5, 1.0, 'test')
